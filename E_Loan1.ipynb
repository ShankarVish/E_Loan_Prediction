# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Financial.csv")

# %%
df.head()
# Out:
#    entry_id  age  pay_schedule  home_owner  income  months_employed  \
# 0   7629673   40     bi-weekly           1    3135                0
# 1   3560428   61        weekly           0    3180                0
# 2   6934997   23        weekly           0    1540                6
# 3   5682812   40     bi-weekly           0    5230                0
# 4   5335819   33  semi-monthly           0    3590                0
#
#    years_employed  current_address_year  personal_account_m  \
# 0               3                     3                   6
# 1               6                     3                   2
# 2               0                     0                   7
# 3               6                     1                   2
# 4               5                     2                   2
#
#    personal_account_y  ...  amount_requested  risk_score  risk_score_2  \
# 0                   2  ...               550       36200      0.737398
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17908 entries, 0 to 17907
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   entry_id              17908 non-null  int64
#  1   age                   17908 non-null  int64
#  2   pay_schedule          17908 non-null  object
#  3   home_owner            17908 non-null  int64
#  4   income                17908 non-null  int64
#  5   months_employed       17908 non-null  int64
#  6   years_employed        17908 non-null  int64
#  7   current_address_year  17908 non-null  int64
#  8   personal_account_m    17908 non-null  int64
#  9   personal_account_y    17908 non-null  int64
#  10  has_debt              17908 non-null  int64
#  11  amount_requested      17908 non-null  int64
#  12  risk_score            17908 non-null  int64
#  13  risk_score_2          17908 non-null  float64
#  14  risk_score_3          17908 non-null  float64
# ...

# %%
# EDA

# %%
df.columns
# Out:
# Index(['entry_id', 'age', 'pay_schedule', 'home_owner', 'income',
#        'months_employed', 'years_employed', 'current_address_year',
#        'personal_account_m', 'personal_account_y', 'has_debt',
#        'amount_requested', 'risk_score', 'risk_score_2', 'risk_score_3',
#        'risk_score_4', 'risk_score_5', 'ext_quality_score',
#        'ext_quality_score_2', 'inquiries_last_month', 'e_signed'],
#       dtype='object')

# %%
df.describe()
# Out:
#            entry_id           age    home_owner        income  \
# count  1.790800e+04  17908.000000  17908.000000  17908.000000
# mean   5.596978e+06     43.015412      0.425173   3657.214653
# std    2.562473e+06     11.873107      0.494383   1504.890063
# min    1.111398e+06     18.000000      0.000000    905.000000
# 25%    3.378999e+06     34.000000      0.000000   2580.000000
# 50%    5.608376e+06     42.000000      0.000000   3260.000000
# 75%    7.805624e+06     51.000000      1.000000   4670.000000
# max    9.999874e+06     96.000000      1.000000   9985.000000
#
#        months_employed  years_employed  current_address_year  \
# count     17908.000000    17908.000000          17908.000000
# mean          1.186006        3.526860              3.584711
# std           2.400897        2.259732              2.751937
# min           0.000000        0.000000              0.000000
# 25%           0.000000        2.000000              2.000000
# ...

# %%
df.isna().any()
# Out:
# entry_id                False
# age                     False
# pay_schedule            False
# home_owner              False
# income                  False
# months_employed         False
# years_employed          False
# current_address_year    False
# personal_account_m      False
# personal_account_y      False
# has_debt                False
# amount_requested        False
# risk_score              False
# risk_score_2            False
# risk_score_3            False
# risk_score_4            False
# risk_score_5            False
# ext_quality_score       False
# ext_quality_score_2     False
# inquiries_last_month    False
# e_signed                False
# dtype: bool

# %%
dataset = df.drop(columns= ['entry_id','pay_schedule','e_signed'])
dataset
# Out:
#        age  home_owner  income  months_employed  years_employed  \
# 0       40           1    3135                0               3
# 1       61           0    3180                0               6
# 2       23           0    1540                6               0
# 3       40           0    5230                0               6
# 4       33           0    3590                0               5
# ...    ...         ...     ...              ...             ...
# 17903   31           0    3245                0               5
# 17904   46           0    6525                0               2
# 17905   46           0    2685                0               5
# 17906   42           0    2515                0               3
# 17907   29           1    2665                0               4
#
#        current_address_year  personal_account_m  personal_account_y  has_debt  \
# 0                         3                   6                   2         1
# ...

# %%
fig = plt.figure(figsize=(15, 12))
plt.suptitle('Histograms of Numerical Columns', fontsize=20)
for i in range(dataset.shape[1]):
    plt.subplot(6, 3, i + 1)
    f = plt.gca()
    f.set_title(dataset.columns.values[i])

    vals = np.size(dataset.iloc[:, i].unique())
    if vals >= 100:
        vals = 100
    
    plt.hist(dataset.iloc[:, i], bins=vals, color='#3F5D7D')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])

# %%
dataset.head()
# Out:
#    age  home_owner  income  months_employed  years_employed  \
# 0   40           1    3135                0               3
# 1   61           0    3180                0               6
# 2   23           0    1540                6               0
# 3   40           0    5230                0               6
# 4   33           0    3590                0               5
#
#    current_address_year  personal_account_m  personal_account_y  has_debt  \
# 0                     3                   6                   2         1
# 1                     3                   2                   7         1
# 2                     0                   7                   1         1
# 3                     1                   2                   7         1
# 4                     2                   2                   8         1
#
#    amount_requested  risk_score  risk_score_2  risk_score_3  risk_score_4  \
# 0               550       36200      0.737398      0.903517      0.487712
# ...

# %%
dataset.corrwith(df.e_signed).plot.bar(
    figsize = (25,10) , title = "Correlation with e-Signed", fontsize = 15, rot = 45, grid = True
)

# rot for rotating column name so that there is good visiblity
# Out:
# <Axes: title={'center': 'Correlation with e-Signed'}>

# %%
## Correlation Matrix
sns.set(style="white")

# Compute the correlation matrix
corr = dataset.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(18, 15))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
# Out:
# <Axes: >

# %% [markdown]
# 1. Compute the Correlation Matrix: The corr() function calculates the correlation coefficients between all pairs of variables in your dataset.
#
# 2. Generate a Mask for the Upper Triangle: Since the correlation matrix is symmetric, and we are interested in visualizing only one half (to avoid redundancy), we create a mask using np.zeros_like() function to create a boolean array of the same shape as the correlation matrix. Then, we set the upper triangle of the mask array to True using np.triu_indices_from() function.
#
# 3. Set up the Matplotlib Figure: We create a matplotlib figure and axis object to hold our heatmap.
#
# 4. Generate a Custom Diverging Colormap: This line generates a custom colormap using sns.diverging_palette() function. This colormap will be used to represent the correlation values in the heatmap.
#
# 5. Draw the Heatmap: Finally, we draw the heatmap using sns.heatmap(). We pass the correlation matrix, the mask to hide the upper triangle, the colormap, and some additional parameters to customize the appearance of the heatmap.
#
# The resulting heatmap provides a visual representation of the correlation between different variables in your dataset. Positive correlations are typically represented in one color shade (e.g., warmer colors), while negative correlations are represented in another color shade (e.g., cooler colors). The intensity of the color represents the strength of the correlation.

# %%
# Feature Engeneering

# %%
import random
import time

# %%
df.head()
# Out:
#    entry_id  age  pay_schedule  home_owner  income  months_employed  \
# 0   7629673   40     bi-weekly           1    3135                0
# 1   3560428   61        weekly           0    3180                0
# 2   6934997   23        weekly           0    1540                6
# 3   5682812   40     bi-weekly           0    5230                0
# 4   5335819   33  semi-monthly           0    3590                0
#
#    years_employed  current_address_year  personal_account_m  \
# 0               3                     3                   6
# 1               6                     3                   2
# 2               0                     0                   7
# 3               6                     1                   2
# 4               5                     2                   2
#
#    personal_account_y  ...  amount_requested  risk_score  risk_score_2  \
# 0                   2  ...               550       36200      0.737398
# ...

# %%
dataset3 = df.drop(columns= ['months_employed'])
dataset3['personal_account_months'] = ((dataset3.personal_account_m) + (dataset3.personal_account_y * 12))
dataset3.head()
# Out:
#    entry_id  age  pay_schedule  home_owner  income  years_employed  \
# 0   7629673   40     bi-weekly           1    3135               3
# 1   3560428   61        weekly           0    3180               6
# 2   6934997   23        weekly           0    1540               0
# 3   5682812   40     bi-weekly           0    5230               6
# 4   5335819   33  semi-monthly           0    3590               5
#
#    current_address_year  personal_account_m  personal_account_y  has_debt  \
# 0                     3                   6                   2         1
# 1                     3                   2                   7         1
# 2                     0                   7                   1         1
# 3                     1                   2                   7         1
# 4                     2                   2                   8         1
#
#    ...  risk_score  risk_score_2  risk_score_3  risk_score_4  risk_score_5  \
# ...

# %%
dataset3.drop(columns=  ['personal_account_m','personal_account_y'])
# Out:
#        entry_id  age  pay_schedule  home_owner  income  years_employed  \
# 0       7629673   40     bi-weekly           1    3135               3
# 1       3560428   61        weekly           0    3180               6
# 2       6934997   23        weekly           0    1540               0
# 3       5682812   40     bi-weekly           0    5230               6
# 4       5335819   33  semi-monthly           0    3590               5
# ...         ...  ...           ...         ...     ...             ...
# 17903   9949728   31       monthly           0    3245               5
# 17904   9442442   46     bi-weekly           0    6525               2
# 17905   9857590   46        weekly           0    2685               5
# 17906   8708471   42     bi-weekly           0    2515               3
# 17907   1498559   29        weekly           1    2665               4
#
#        current_address_year  has_debt  amount_requested  risk_score  \
# ...

# %%
dataset3 = pd.get_dummies(dataset3)
dataset3.columns
# Out:
# Index(['entry_id', 'age', 'home_owner', 'income', 'years_employed',
#        'current_address_year', 'personal_account_m', 'personal_account_y',
#        'has_debt', 'amount_requested', 'risk_score', 'risk_score_2',
#        'risk_score_3', 'risk_score_4', 'risk_score_5', 'ext_quality_score',
#        'ext_quality_score_2', 'inquiries_last_month', 'e_signed',
#        'personal_account_months', 'pay_schedule_bi-weekly',
#        'pay_schedule_monthly', 'pay_schedule_semi-monthly',
#        'pay_schedule_weekly'],
#       dtype='object')

# %%
dataset3['pay_schedule_semi-monthly'].value_counts().unique()
# Out:
# array([15904,  2004])

# %%
dataset3 = dataset3.drop(columns=['pay_schedule_semi-monthly'])

# %%
# Removing extra columns
response = dataset3['e_signed']
users = dataset3['entry_id']
dataset3 = dataset3.drop(columns = ['e_signed', 'entry_id'])

# %%
dataset3.head()
# Out:
#    age  home_owner  income  years_employed  current_address_year  \
# 0   40           1    3135               3                     3
# 1   61           0    3180               6                     3
# 2   23           0    1540               0                     0
# 3   40           0    5230               6                     1
# 4   33           0    3590               5                     2
#
#    personal_account_m  personal_account_y  has_debt  amount_requested  \
# 0                   6                   2         1               550
# 1                   2                   7         1               600
# 2                   7                   1         1               450
# 3                   2                   7         1               700
# 4                   2                   8         1              1100
#
#    risk_score  ...  risk_score_3  risk_score_4  risk_score_5  \
# 0       36200  ...      0.903517      0.487712      0.515977
# ...

# %%
# Train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test =  train_test_split(dataset3, response, test_size= 0.2,  random_state= 0 )

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
X_train2 = pd.DataFrame(sc_X.fit_transform(X_train))
X_test2 = pd.DataFrame(sc_X.transform(X_test))
X_train2.columns = X_train.columns.values
X_test2.columns = X_test.columns.values
X_train2.index = X_train.index.values
X_test2.index = X_test.index.values
X_train = X_train2
X_test = X_test2

# %%
# Model Building
# Logistic regression
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0, penalty = 'l1', solver = 'liblinear') 
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(penalty='l1', random_state=0, solver='liblinear')

# %% [markdown]
# In the context of logistic regression, a solver is an optimization algorithm used to minimize the cost function during the model training process. The choice of solver affects the efficiency and accuracy of the logistic regression model.
#
# Different solvers have different characteristics and are suitable for different types of datasets. Here are some common solvers used in logistic regression:
#
# 'liblinear': This solver is suitable for small and medium-sized datasets. It supports both L1 and L2 penalties. It's efficient for datasets with a large number of features.
#
# 'lbfgs' (Limited-memory Broyden–Fletcher–Goldfarb–Shanno): This solver is efficient for small datasets. It's a quasi-Newton method that approximates the second derivative matrix of the cost function. It supports only L2 penalty.
#
# 'newton-cg': This solver is also based on the Newton method. It's efficient for small datasets and supports both L1 and L2 penalties.
#
# 'sag' (Stochastic Average Gradient): This solver is suitable for large datasets. It's an optimization algorithm that uses a stochastic gradient descent approach. It supports only L2 penalty.
#
# 'saga': This solver is an extension of 'sag' that also supports L1 penalty. It's suitable for large datasets and can handle both L1 and L2 penalties.
#
# When choosing a solver, consider the size of your dataset, the number of features, and whether you want to use L1 or L2 regularization. It's often a good idea to experiment with different solvers and penalties to find the combination that works best for your specific problem.

# %%
# Prediction
y_pred = classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, recall_score 
acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
pre = precision_score(y_test, y_pred)
rec = recall_score(y_test, y_pred)

# %%
results = pd.DataFrame([['Linear Regression (Lasso)', acc, pre, rec, f1]],
               columns = ['Model', 'Accuracy', 'Precision', 'Recall', 'F1 Score'])
results
# Out:
#                        Model  Accuracy  Precision    Recall  F1 Score
# 0  Linear Regression (Lasso)  0.571468   0.583867  0.709544  0.640599

# %%
# Support Vector Machine SVM(Linear)
from sklearn.svm import SVC
classifier = SVC(random_state= 0 , kernel = 'linear')
classifier.fit(X_train,y_train)
# Out:
# SVC(kernel='linear', random_state=0)

# %%
# Prediction
y_pred = classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, recall_score 
acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
pre = precision_score(y_test, y_pred)
rec = recall_score(y_test, y_pred)

# %%
model_results = pd.DataFrame([['SVM(Linear)', acc, pre, rec, f1]],
               columns = ['Model', 'Accuracy', 'Precision', 'Recall', 'F1 Score'])
model_results
# Out:
#          Model  Accuracy  Precision    Recall  F1 Score
# 0  SVM(Linear)  0.572864   0.583055  0.724585  0.646161

# %%
# Assuming 'results' and 'model_results' are DataFrames
results = pd.concat([results, model_results], ignore_index=True)
results
# Out:
#                        Model  Accuracy  Precision    Recall  F1 Score
# 0  Linear Regression (Lasso)  0.571468   0.583867  0.709544  0.640599
# 1                SVM(Linear)  0.572864   0.583055  0.724585  0.646161

# %%
# Support Vector Machine SVM(rbf)
from sklearn.svm import SVC
classifier = SVC(random_state= 0 , kernel = 'rbf')
classifier.fit(X_train,y_train)
# Out:
# SVC(random_state=0)

# %%
# Prediction
y_pred = classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, recall_score 
acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
pre = precision_score(y_test, y_pred)
rec = recall_score(y_test, y_pred)

# %%
model_results1 = pd.DataFrame([['SVM(rbf)', acc, pre, rec, f1]],
               columns = ['Model', 'Accuracy', 'Precision', 'Recall', 'F1 Score'])
model_results1
# Out:
#       Model  Accuracy  Precision    Recall  F1 Score
# 0  SVM(rbf)  0.605528   0.618718  0.696058  0.655113

# %%
# Assuming 'results' and 'model_results' are DataFrames
results = pd.concat([results, model_results,model_results1], ignore_index=True)
results
# Out:
#                        Model  Accuracy  Precision    Recall  F1 Score
# 0  Linear Regression (Lasso)  0.571468   0.583867  0.709544  0.640599
# 1                SVM(Linear)  0.572864   0.583055  0.724585  0.646161
# 2                SVM(Linear)  0.572864   0.583055  0.724585  0.646161
# 3                   SVM(rbf)  0.605528   0.618718  0.696058  0.655113

# %%
from sklearn.ensemble import RandomForestClassifier
classifier = RandomForestClassifier(random_state= 0 ,  n_estimators= 100 , criterion='entropy')
classifier.fit(X_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', random_state=0)

# %%
# Prediction
y_pred = classifier.predict(X_test)
from sklearn.metrics import confusion_matrix, accuracy_score, f1_score, precision_score, recall_score 
acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
pre = precision_score(y_test, y_pred)
rec = recall_score(y_test, y_pred)

# %%
model_results2 = pd.DataFrame([['Decsion Tree', acc, pre, rec, f1]],
               columns = ['Model', 'Accuracy', 'Precision', 'Recall', 'F1 Score'])
model_results2
# Out:
#           Model  Accuracy  Precision    Recall  F1 Score
# 0  Decsion Tree  0.633724   0.652626  0.683091  0.667511

# %%
results = pd.concat([results, model_results,model_results1,model_results2], ignore_index=True)
results
# Out:
#                        Model  Accuracy  Precision    Recall  F1 Score
# 0  Linear Regression (Lasso)  0.571468   0.583867  0.709544  0.640599
# 1                SVM(Linear)  0.572864   0.583055  0.724585  0.646161
# 2                SVM(Linear)  0.572864   0.583055  0.724585  0.646161
# 3                   SVM(rbf)  0.605528   0.618718  0.696058  0.655113
# 4                SVM(Linear)  0.572864   0.583055  0.724585  0.646161
# 5                   SVM(rbf)  0.605528   0.618718  0.696058  0.655113
# 6               Decsion Tree  0.633724   0.652626  0.683091  0.667511

# %%
from sklearn.model_selection import cross_val_score
accuracies = cross_val_score(estimator = classifier, X = X_train, y = y_train, cv = 10 )
print("Random Forest Classifier Accuracy: %0.2f (+/- %0.2f)"  % (accuracies.mean(), accuracies.std() * 2))
# Out:
# Random Forest Classifier Accuracy: 0.63 (+/- 0.02)

# %%
# Applying Grid Search
 # Round 1: Entropy
parameters = {"max_depth": [3, None],
              "max_features": [1, 5, 10],
              'min_samples_split': [2, 5, 10],
              'min_samples_leaf': [1, 5, 10],
              "bootstrap": [True, False],
              "criterion": ["entropy"]}

# %%
from sklearn.model_selection import GridSearchCV
grid_search = GridSearchCV(estimator = classifier, # Make sure classifier points to the RF model
                           param_grid = parameters,
                           scoring = "accuracy",
                           cv = 10,
                           n_jobs = -1)

# %%
t0 = time.time()
grid_search = grid_search.fit(X_train, y_train)
t1 = time.time()
print("Took %0.2f seconds" % (t1 - t0))
# Out:
# Took 583.70 seconds

# %%
rf_best_accuracy = grid_search.best_score_
rf_best_parameters = grid_search.best_params_
rf_best_accuracy, rf_best_parameters
# Out:
# (0.6378636353004012,
#  {'bootstrap': True,
#   'criterion': 'entropy',
#   'max_depth': None,
#   'max_features': 10,
#   'min_samples_leaf': 10,
#   'min_samples_split': 2})

# %%
# Round 2: Entropy
parameters = {"max_depth": [None],
              "max_features": [3, 5, 7],
              'min_samples_split': [8, 10, 12],
              'min_samples_leaf': [1, 2, 3],
              "bootstrap": [True],
              "criterion": ["entropy"]}

# %%
from sklearn.model_selection import GridSearchCV
grid_search = GridSearchCV(estimator = classifier, # Make sure classifier points to the RF model
                           param_grid = parameters,
                           scoring = "accuracy",
                           cv = 10,
                           n_jobs = -1)

# %%
t0 = time.time()
grid_search = grid_search.fit(X_train, y_train)
t1 = time.time()
print("Took %0.2f seconds" % (t1 - t0))
# Out:
# Took 168.98 seconds

# %%
rf_best_accuracy = grid_search.best_score_
rf_best_parameters = grid_search.best_params_
rf_best_accuracy, rf_best_parameters
# Out:
# (0.6380034950313246,
#  {'bootstrap': True,
#   'criterion': 'entropy',
#   'max_depth': None,
#   'max_features': 7,
#   'min_samples_leaf': 2,
#   'min_samples_split': 12})

# %%
# Predicting Test Set
y_pred = grid_search.predict(X_test)
acc = accuracy_score(y_test, y_pred)
pre = precision_score(y_test, y_pred)
rec = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

model_results = pd.DataFrame([['Random Forest (n=100, GSx2 + Entropy)', acc, pre, rec, f1]],
               columns = ['Model', 'Accuracy', 'Precision', 'Recall', 'F1 Score'])

results = pd.concat([results, model_results], ignore_index=True)

# %%
results
# Out:
#                                    Model  Accuracy  Precision    Recall  \
# 0              Linear Regression (Lasso)  0.571468   0.583867  0.709544
# 1                            SVM(Linear)  0.572864   0.583055  0.724585
# 2                            SVM(Linear)  0.572864   0.583055  0.724585
# 3                               SVM(rbf)  0.605528   0.618718  0.696058
# 4                            SVM(Linear)  0.572864   0.583055  0.724585
# 5                               SVM(rbf)  0.605528   0.618718  0.696058
# 6                           Decsion Tree  0.633724   0.652626  0.683091
# 7  Random Forest (n=100, GSx2 + Entropy)  0.640424   0.653698  0.705913
#
#    F1 Score
# 0  0.640599
# 1  0.646161
# 2  0.646161
# 3  0.655113
# 4  0.646161
# 5  0.655113
# 6  0.667511
# 7  0.678803

# %%
# Round 1: Gini
parameters = {"max_depth": [3, None],
              "max_features": [1, 5, 10],
              'min_samples_split': [2, 5, 10],
              'min_samples_leaf': [1, 5, 10],
              "bootstrap": [True, False],
              "criterion": ["gini"]}

from sklearn.model_selection import GridSearchCV
grid_search = GridSearchCV(estimator = classifier, # Make sure classifier points to the RF model
                           param_grid = parameters,
                           scoring = "accuracy",
                           cv = 10,
                           n_jobs = -1)

t0 = time.time()
grid_search = grid_search.fit(X_train, y_train)
t1 = time.time()
print("Took %0.2f seconds" % (t1 - t0))

rf_best_accuracy = grid_search.best_score_
rf_best_parameters = grid_search.best_params_
rf_best_accuracy, rf_best_parameters
# Out:
# Took 467.35 seconds
# (0.6373055608618869,
#  {'bootstrap': False,
#   'criterion': 'gini',
#   'max_depth': None,
#   'max_features': 5,
#   'min_samples_leaf': 10,
#   'min_samples_split': 2})

# %%
# Round 2: Gini
parameters = {"max_depth": [None],
              "max_features": [8, 10, 12],
              'min_samples_split': [2, 3, 4],
              'min_samples_leaf': [8, 10, 12],
              "bootstrap": [True],
              "criterion": ["gini"]}

from sklearn.model_selection import GridSearchCV
grid_search = GridSearchCV(estimator = classifier, # Make sure classifier points to the RF model
                           param_grid = parameters,
                           scoring = "accuracy",
                           cv = 10,
                           n_jobs = -1)

t0 = time.time()
grid_search = grid_search.fit(X_train, y_train)
t1 = time.time()
print("Took %0.2f seconds" % (t1 - t0))

rf_best_accuracy = grid_search.best_score_
rf_best_parameters = grid_search.best_params_
rf_best_accuracy, rf_best_parameters
# Out:
# Took 295.99 seconds
# (0.6394690495775944,
#  {'bootstrap': True,
#   'criterion': 'gini',
#   'max_depth': None,
#   'max_features': 8,
#   'min_samples_leaf': 8,
#   'min_samples_split': 2})

# %% [markdown]
# Gini impurity and entropy are both measures used in decision tree algorithms to evaluate the quality of a split. They are metrics that quantify the uncertainty or randomness of a dataset. Here's a comparison between the two:
#
# 1. **Definition**:
#    - **Gini impurity**: It measures the probability of incorrectly classifying a randomly chosen element if it were randomly labeled according to the distribution of labels in the node.
#    - **Entropy**: It measures the average amount of information needed to classify a sample in the dataset.
#
# 2. **Formula**:
#    - **Gini impurity**: \( Gini = 1 - \sum_{i=1}^{n} p_i^2 \), where \( p_i \) is the probability of an item being classified to a particular class.
#    - **Entropy**: \( Entropy = -\sum_{i=1}^{n} p_i \log_2(p_i) \), where \( p_i \) is the probability of an item being classified to a particular class.
#
# 3. **Range**:
#    - **Gini impurity**: It ranges from 0 to 0.5, where 0 indicates all elements belong to a single class and 0.5 indicates equally distributed elements among all classes.
#    - **Entropy**: It ranges from 0 to 1, where 0 indicates all elements belong to a single class and 1 indicates equal distribution among all classes.
#
# 4. **Calculation**:
#    - **Gini impurity**: Typically faster to compute than entropy, as it doesn't involve logarithmic calculations.
#    - **Entropy**: Involves logarithmic calculations, which might be slower compared to Gini impurity.
#
# 5. **Decision Trees**:
#    - **Gini impurity**: Often used in CART (Classification and Regression Trees) algorithm.
#    - **Entropy**: Frequently used in ID3, C4.5, and related algorithms.
#
# 6. **Usage**:
#    - **Gini impurity**: Tends to favor larger partitions and often results in slightly shorter trees.
#    - **Entropy**: Tends to produce more balanced trees compared to Gini impurity.
#
# 7. **Effect on Model**:
#    - **Gini impurity**: Generally results in a decision tree with decision boundaries that are orthogonal to the feature axes.
#    - **Entropy**: May result in decision boundaries that are not necessarily orthogonal to the feature axes.
#
# In practice, the choice between Gini impurity and entropy often doesn't make a substantial difference in the performance of decision trees, though it may affect the structure of the resulting tree. Both are valid metrics for assessing splits in decision trees, and the choice between them often depends on the specific problem and the preference of the practitioner.

# %%
y_pred = grid_search.predict(X_test)
acc = accuracy_score(y_test, y_pred)
prec = precision_score(y_test, y_pred)
rec = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

model_results = pd.DataFrame([['Random Forest (n=100, GSx2 + Gini)', acc, prec, rec, f1]],
               columns = ['Model', 'Accuracy', 'Precision', 'Recall', 'F1 Score'])

results = pd.concat([results, model_results], ignore_index=True)

# %%
results
# Out:
#                                    Model  Accuracy  Precision    Recall  \
# 0              Linear Regression (Lasso)  0.571468   0.583867  0.709544
# 1                            SVM(Linear)  0.572864   0.583055  0.724585
# 2                            SVM(Linear)  0.572864   0.583055  0.724585
# 3                               SVM(rbf)  0.605528   0.618718  0.696058
# 4                            SVM(Linear)  0.572864   0.583055  0.724585
# 5                               SVM(rbf)  0.605528   0.618718  0.696058
# 6                           Decsion Tree  0.633724   0.652626  0.683091
# 7  Random Forest (n=100, GSx2 + Entropy)  0.640424   0.653698  0.705913
# 8     Random Forest (n=100, GSx2 + Gini)  0.637912   0.654128  0.694502
#
#    F1 Score
# 0  0.640599
# 1  0.646161
# 2  0.646161
# 3  0.655113
# 4  0.646161
# 5  0.655113
# 6  0.667511
# 7  0.678803
# 8  0.673711

# %%
## EXTRA: Confusion Matrix
cm = confusion_matrix(y_test, y_pred) # rows = truth, cols = prediction
df_cm = pd.DataFrame(cm, index = (0, 1), columns = (0, 1))
plt.figure(figsize = (10,7))
sns.set(font_scale=1.4)
sns.heatmap(df_cm, annot=True, fmt='g')
print("Test Data Accuracy: %0.4f" % accuracy_score(y_test, y_pred))
# Out:
# Test Data Accuracy: 0.6379

# %%
# Formatting Final Results

final_results = pd.concat([y_test, users], axis = 1).dropna()
final_results['predictions'] = y_pred
final_results = final_results[['entry_id', 'e_signed', 'predictions']]

# %%
final_results.head()
# Out:
#        entry_id  e_signed  predictions
# 3629    8825262       1.0            0
# 1820    9216889       1.0            1
# 6685    1762129       0.0            1
# 17241   7249770       1.0            1
# 8332    5967375       1.0            1
